# %%
# %matplotlib inline

import pandas as pd
import dateutil
import numpy as np

# %%
df = pd.read_csv('beatles.csv')

# %%
df
# Out:
#    Unnamed: 0                                  Title    Released  \
# 0           0                    Yesterday and Today  1966-06-15
# 1           1                               Revolver  1966-08-05
# 2           2                               Revolver  1966-08-08
# 3           3  Sgt. Pepper's Lonely Hearts Club Band  1967-06-01
# 4           4                   Magical Mystery Tour  1967-11-27
# 5           5                            The Beatles  1968-11-22
# 6           6                       Yellow Submarine  1969-01-13
# 7           7                             Abbey Road  1969-09-26
# 8           8                              Let It Be  1970-05-08
#
#                           Label  UK Chart Position  US Chart Position  \
# 0                   Capitol(US)                NaN                1.0
# 1                Parlophone(UK)                1.0                NaN
# 2                Capitol(US)[C]                NaN                1.0
# 3   Parlophone(UK), Capitol(US)                1.0                1.0
# 4   Parlophone(UK), Capitol(US)                NaN                1.0
# 5        Apple(UK), Capitol(US)                1.0                1.0
# 6        Apple(UK), Capitol(US)                3.0                2.0
# 7        Apple(UK), Capitol(US)                1.0                1.0
# 8  Apple(UK),United Artists(US)                1.0                1.0
#
#   BPI Certification RIAA Certification  Count Songs  Year
# 0               NaN         2xPlatinum           11  1966
# 1          Platinum                NaN           14  1966
# 2               NaN         5xPlatinum           14  1966
# 3        3xPlatinum        11xPlatinum           13  1967
# 4          Platinum         6xPlatinum           11  1967
# 5          Platinum        19xPlatinum           30  1968
# 6            Silver           Platinum            6  1969
# 7        2xPlatinum        12xPlatinum           17  1969
# 8              Gold         4xPlatinum           12  1970

# %%
df['Count Songs'].plot()

# %%
df[[x for x in df.columns if 'Position' in x]].plot()

# %%
ax = df[[x for x in df.columns if 'Position' in x]].plot()
ax.set_ylim(5, -1)
# Out:
# (5, -1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Released', 'Label', 'UK Chart Position',
#        'US Chart Position', 'BPI Certification', 'RIAA Certification',
#        'Count Songs', 'Year'],
#       dtype='object')

# %%
ax = df.set_index('Title')[[x for x in df.columns if 'Position' in x]].plot()
ax.set_ylim(5, -1)
# Out:
# (5, -1)

# %%
ax = df.set_index('Title')[[x for x in df.columns if 'Position' in x]].plot()
ax.set_ylim(5, -1)
labels = df.set_index('Title').index
ax.set_xticklabels(labels, rotation=45)
# Out:
# [<matplotlib.text.Text at 0x7f59d7403c18>,
#  <matplotlib.text.Text at 0x7f59d746d6d8>,
#  <matplotlib.text.Text at 0x7f59d748a5f8>,
#  <matplotlib.text.Text at 0x7f59d748a978>,
#  <matplotlib.text.Text at 0x7f59d747d080>,
#  <matplotlib.text.Text at 0x7f59d747dc50>,
#  <matplotlib.text.Text at 0x7f59d743a048>,
#  <matplotlib.text.Text at 0x7f59d743ad30>,
#  <matplotlib.text.Text at 0x7f59d7484160>]

# %%
ax = df.set_index('Title')[[x for x in df.columns if 'Position' in x]].plot()
ax.set_ylim(5, -1)
labels = df.set_index('Title').index
ax.set_xticklabels(labels, rotation=45, rotation_mode='anchor')
# Out:
# [<matplotlib.text.Text at 0x7f59d742e160>,
#  <matplotlib.text.Text at 0x7f59d748f128>,
#  <matplotlib.text.Text at 0x7f59d71ff860>,
#  <matplotlib.text.Text at 0x7f59d7277e80>,
#  <matplotlib.text.Text at 0x7f59d747f860>,
#  <matplotlib.text.Text at 0x7f59d74882b0>,
#  <matplotlib.text.Text at 0x7f59d7488cc0>,
#  <matplotlib.text.Text at 0x7f59d747a710>,
#  <matplotlib.text.Text at 0x7f59d7446160>]

# %%
ax = df.set_index('Title')[[x for x in df.columns if 'Position' in x]].plot(
  marker='8', alpha=.3
)
ax.set_ylim(5, -1)
labels = df.set_index('Title').index
ax.set_xticklabels(labels, rotation=45, rotation_mode='anchor')
# Out:
# [<matplotlib.text.Text at 0x7f59d7212438>,
#  <matplotlib.text.Text at 0x7f59d79cdf60>,
#  <matplotlib.text.Text at 0x7f59d71c7978>,
#  <matplotlib.text.Text at 0x7f59d71cdc50>,
#  <matplotlib.text.Text at 0x7f59d71d06a0>,
#  <matplotlib.text.Text at 0x7f59d71d50f0>,
#  <matplotlib.text.Text at 0x7f59d71d5b00>,
#  <matplotlib.text.Text at 0x7f59d71d8550>,
#  <matplotlib.text.Text at 0x7f59d71d8f60>]
