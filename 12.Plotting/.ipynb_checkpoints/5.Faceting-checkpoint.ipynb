# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('beatles.csv', index_col=0)

# %%
df
# Out:
#                                    Title    Released  \
# 0                    Yesterday and Today  1966-06-15
# 1                               Revolver  1966-08-05
# 2                               Revolver  1966-08-08
# 3  Sgt. Pepper's Lonely Hearts Club Band  1967-06-01
# 4                   Magical Mystery Tour  1967-11-27
# 5                            The Beatles  1968-11-22
# 6                       Yellow Submarine  1969-01-13
# 7                             Abbey Road  1969-09-26
# 8                              Let It Be  1970-05-08
#
#                           Label  UK Chart Position  US Chart Position  \
# 0                   Capitol(US)                NaN                1.0
# 1                Parlophone(UK)                1.0                NaN
# 2                Capitol(US)[C]                NaN                1.0
# 3   Parlophone(UK), Capitol(US)                1.0                1.0
# 4   Parlophone(UK), Capitol(US)                NaN                1.0
# 5        Apple(UK), Capitol(US)                1.0                1.0
# 6        Apple(UK), Capitol(US)                3.0                2.0
# 7        Apple(UK), Capitol(US)                1.0                1.0
# 8  Apple(UK),United Artists(US)                1.0                1.0
#
#   BPI Certification RIAA Certification  Count Songs  Year
# 0               NaN         2xPlatinum           11  1966
# 1          Platinum                NaN           14  1966
# 2               NaN         5xPlatinum           14  1966
# 3        3xPlatinum        11xPlatinum           13  1967
# 4          Platinum         6xPlatinum           11  1967
# 5          Platinum        19xPlatinum           30  1968
# 6            Silver           Platinum            6  1969
# 7        2xPlatinum        12xPlatinum           17  1969
# 8              Gold         4xPlatinum           12  1970

# %% [markdown]
# ## Faceting

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f64f77ec588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64f5296898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f64f5258160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64f5220198>]], dtype=object)

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# /home/k/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x7f64f4992198>,
#   <matplotlib.lines.Line2D at 0x7f64f49a55f8>,
#   <matplotlib.lines.Line2D at 0x7f64f49b6f28>,
#   <matplotlib.lines.Line2D at 0x7f64f494d898>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f64f499bc18>,
#   <matplotlib.lines.Line2D at 0x7f64f499bd30>,
#   <matplotlib.lines.Line2D at 0x7f64f49ace48>,
#   <matplotlib.lines.Line2D at 0x7f64f49b2da0>,
#   <matplotlib.lines.Line2D at 0x7f64f4943eb8>,
#   <matplotlib.lines.Line2D at 0x7f64f4943fd0>,
#   <matplotlib.lines.Line2D at 0x7f64f495a828>,
#   <matplotlib.lines.Line2D at 0x7f64f495af60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f64f49a0da0>,
#   <matplotlib.lines.Line2D at 0x7f64f49b6e10>,
#   <matplotlib.lines.Line2D at 0x7f64f494d780>,
#   <matplotlib.lines.Line2D at 0x7f64f4960fd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f64f49a0588>,
#   <matplotlib.lines.Line2D at 0x7f64f49b2eb8>,
#   <matplotlib.lines.Line2D at 0x7f64f4948828>,
#   <matplotlib.lines.Line2D at 0x7f64f4960198>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f64f4992ba8>,
#   <matplotlib.lines.Line2D at 0x7f64f4992cc0>,
#   <matplotlib.lines.Line2D at 0x7f64f49a5d68>,
#   <matplotlib.lines.Line2D at 0x7f64f49acd30>,
#   <matplotlib.lines.Line2D at 0x7f64f49bde48>,
#   <matplotlib.lines.Line2D at 0x7f64f49bdf60>,
#   <matplotlib.lines.Line2D at 0x7f64f49537b8>,
#   <matplotlib.lines.Line2D at 0x7f64f4953fd0>]}

# %%
pos = [x for x in df.columns if 'Position' in x]
pos
# Out:
# ['UK Chart Position', 'US Chart Position']

# %%
df[pos].boxplot()
# Out:
# /home/k/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x7f64f4a61518>,
#   <matplotlib.lines.Line2D at 0x7f64f4aeceb8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f64f4ba3b70>,
#   <matplotlib.lines.Line2D at 0x7f64f4b99828>,
#   <matplotlib.lines.Line2D at 0x7f64f4b14d68>,
#   <matplotlib.lines.Line2D at 0x7f64f4b4bc18>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f64f49c4860>,
#   <matplotlib.lines.Line2D at 0x7f64f4af2630>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f64f4b994a8>,
#   <matplotlib.lines.Line2D at 0x7f64f4b4b6d8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f64f4a61748>,
#   <matplotlib.lines.Line2D at 0x7f64f4ba3eb8>,
#   <matplotlib.lines.Line2D at 0x7f64f4aec1d0>,
#   <matplotlib.lines.Line2D at 0x7f64f4b142b0>]}

# %%
df[pos].describe()
# Out:
#        UK Chart Position  US Chart Position
# count           6.000000           8.000000
# mean            1.333333           1.125000
# std             0.816497           0.353553
# min             1.000000           1.000000
# 25%             1.000000           1.000000
# 50%             1.000000           1.000000
# 75%             1.000000           1.000000
# max             3.000000           2.000000

# %%
df.boxplot(by='Year')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10ca5f7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c7c0128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c874b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c61cb00>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10ca5bdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd84908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd8c710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cdcd4e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10ce1d9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ce5f320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cea8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cee7160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10cf32278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cf4ef28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cfbb1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d0046a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10d03fc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d08f358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c572748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d0f7668>]], dtype=object)

# %%
scatter_matrix(df)
plt.tight_layout()
