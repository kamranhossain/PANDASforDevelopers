# %%
# %matplotlib inline

import pandas as pd

# %%
df = pd.read_csv('beatles.csv')

# %% [markdown]
# ## Histograms

# %%
df
# Out:
#    Unnamed: 0                                  Title    Released  \
# 0           0                    Yesterday and Today  1966-06-15
# 1           1                               Revolver  1966-08-05
# 2           2                               Revolver  1966-08-08
# 3           3  Sgt. Pepper's Lonely Hearts Club Band  1967-06-01
# 4           4                   Magical Mystery Tour  1967-11-27
# 5           5                            The Beatles  1968-11-22
# 6           6                       Yellow Submarine  1969-01-13
# 7           7                             Abbey Road  1969-09-26
# 8           8                              Let It Be  1970-05-08
#
#                           Label  UK Chart Position  US Chart Position  \
# 0                   Capitol(US)                NaN                1.0
# 1                Parlophone(UK)                1.0                NaN
# 2                Capitol(US)[C]                NaN                1.0
# 3   Parlophone(UK), Capitol(US)                1.0                1.0
# 4   Parlophone(UK), Capitol(US)                NaN                1.0
# 5        Apple(UK), Capitol(US)                1.0                1.0
# 6        Apple(UK), Capitol(US)                3.0                2.0
# 7        Apple(UK), Capitol(US)                1.0                1.0
# 8  Apple(UK),United Artists(US)                1.0                1.0
#
#   BPI Certification RIAA Certification  Count Songs  Year
# 0               NaN         2xPlatinum           11  1966
# 1          Platinum                NaN           14  1966
# 2               NaN         5xPlatinum           14  1966
# 3        3xPlatinum        11xPlatinum           13  1967
# 4          Platinum         6xPlatinum           11  1967
# 5          Platinum        19xPlatinum           30  1968
# 6            Silver           Platinum            6  1969
# 7        2xPlatinum        12xPlatinum           17  1969
# 8              Gold         4xPlatinum           12  1970

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f78b9065828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f78b6b11748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78b6ad4898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f78b6a9d7f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78b6a586d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f78b6a26a20>]], dtype=object)

# %%
import matplotlib.pyplot as plt

df.hist()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-af413c8f9802> in <module>()
#       2
#       3 df.hist()
# ----> 4 plt.tight_layout()
#
# /home/k/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1377
#    1378     fig = gcf()
# -> 1379     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1380
#    1381
#
# /home/k/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1752                                          renderer,
#    1753                                          pad=pad, h_pad=h_pad, w_pad=w_pad,
# -> 1754                                          rect=rect)
#    1755
#    1756         self.subplots_adjust(**kwargs)
#
# /home/k/anaconda3/lib/python3.5/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     347                                      subplot_list=subplot_list,
#     348                                      ax_bbox_list=ax_bbox_list,
# --> 349                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     350
#     351     if rect is not None:
#
# /home/k/anaconda3/lib/python3.5/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     126         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots])
#     127         tight_bbox = TransformedBbox(tight_bbox_raw,
# --> 128                                      fig.transFigure.inverted())
#     129
#     130         row1, col1 = divmod(num1, cols)
#
# /home/k/anaconda3/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, bbox, transform, **kwargs)
#    1069         *transform*: a 2D :class:`Transform`
#    1070         """
# -> 1071         if not bbox.is_bbox:
#    1072             raise ValueError("'bbox' is not a bbox")
#    1073         if not isinstance(transform, Transform):
#
# AttributeError: 'NoneType' object has no attribute 'is_bbox'

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Title                  object
# Released               object
# Label                  object
# UK Chart Position     float64
# US Chart Position     float64
# BPI Certification      object
# RIAA Certification     object
# Count Songs             int64
# Year                    int64
# dtype: object

# %%
num_cols = df.dtypes != object

num_cols
# Out:
# Unnamed: 0             True
# Title                 False
# Released              False
# Label                 False
# UK Chart Position      True
# US Chart Position      True
# BPI Certification     False
# RIAA Certification    False
# Count Songs            True
# Year                   True
# dtype: bool

# %%
mask = df.dtypes != object
df.dtypes[mask]
# Out:
# Unnamed: 0             int64
# UK Chart Position    float64
# US Chart Position    float64
# Count Songs            int64
# Year                   int64
# dtype: object

# %%
mask = df.dtypes != object
df.dtypes[mask].index
# Out:
# Index(['Unnamed: 0', 'UK Chart Position', 'US Chart Position', 'Count Songs',
#        'Year'],
#       dtype='object')

# %%
mask = df.dtypes != object
cols = df.dtypes[mask].index
df[cols].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f78b5ec7780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f78b5dd94e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78b5daa0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f78b5d635c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78b5d32080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f78b5ced1d0>]], dtype=object)

# %%
import matplotlib.pyplot as plt

num_cols = df.dtypes != object

cols = df.dtypes[num_cols].index
df[cols[:4]].hist()
plt.tight_layout()

# %%
df.plot.hist()

# %%
df[[x for x in df.columns if 'Year' not in x]].plot.hist()

# %%
df[[x for x in df.columns if 'Chart' in x]].plot.hist()

# %%
df['Count Songs'].plot.hist()

# %%
df[['Count Songs']].plot.hist()

# %%
df[['Count Songs']].plot.hist(color='r', alpha=.3)

# %%
df[['Count Songs']].plot.hist(color='r', alpha=.3, bins=3)

# %%
df[['Count Songs']].plot.hist(color='r', alpha=.3, bins=20)

# %%
df[['Count Songs']].plot.hist(cumulative=True)

# %%
df[['Count Songs']].plot.hist(cumulative=True, normed=True)

# %%
df[['Count Songs']].plot.hist(normed=True)
