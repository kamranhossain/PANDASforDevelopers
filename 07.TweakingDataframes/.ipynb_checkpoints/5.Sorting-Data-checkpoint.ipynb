# %% [markdown]
# # Sorting Data

# %%
import pandas as pd

# %%
df = pd.read_json('{"3PA":{"0.0":11.1,"1.0":8.1,"2.0":7.9,"3.0":7.7,"4.0":4.7},"3PM":{"0.0":5.1,"1.0":3.6,"2.0":3.3,"3.0":3.5,"4.0":2.1},"League":{"0.0":"NBA","1.0":"NBA","2.0":"NBA","3.0":"NBA","4.0":"NBA"},"PTS":{"0.0":32.0,"1.0":23.8,"2.0":24.0,"3.0":22.9,"4.0":14.7},"Team":{"0.0":"Golden State","1.0":"Golden State","2.0":"Golden State","3.0":"Golden State","4.0":"Golden State"},"year":{"0.0":"2015-2016","1.0":"2014-2015","2.0":"2013-2014","3.0":"2012-2013","4.0":"2011-2012"},"%3 PTS":{"0.0":0.478125,"1.0":0.4537815126,"2.0":0.4125,"3.0":0.4585152838,"4.0":0.4285714286},"per3":{"0.0":47.8125,"1.0":45.3781512605,"2.0":41.25,"3.0":45.8515283843,"4.0":42.8571428571}}')

# %%
df
# Out:
#                        %3 PTS   3PA  3PM League   PTS          Team  \
# 1970-01-01 00:00:00  0.478125  11.1  5.1    NBA  32.0  Golden State
# 1970-01-01 00:00:01  0.453782   8.1  3.6    NBA  23.8  Golden State
# 1970-01-01 00:00:02  0.412500   7.9  3.3    NBA  24.0  Golden State
# 1970-01-01 00:00:03  0.458515   7.7  3.5    NBA  22.9  Golden State
# 1970-01-01 00:00:04  0.428571   4.7  2.1    NBA  14.7  Golden State
#
#                           per3       year
# 1970-01-01 00:00:00  47.812500  2015-2016
# 1970-01-01 00:00:01  45.378151  2014-2015
# 1970-01-01 00:00:02  41.250000  2013-2014
# 1970-01-01 00:00:03  45.851528  2012-2013
# 1970-01-01 00:00:04  42.857143  2011-2012

# %%
df.set_value(5,'year', '2016-2017')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/k/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in set_value(self, index, col, value, takeable)
#    1863             engine = self.index._engine
# -> 1864             engine.set_value(series._values, index, value)
#    1865             return self
#
# pandas/index.pyx in pandas.index.IndexEngine.set_value (pandas/index.c:3600)()
#
# pandas/index.pyx in pandas.index.IndexEngine.set_value (pandas/index.c:3426)()
#
# pandas/index.pyx in pandas.index.DatetimeEngine.get_loc (pandas/index.c:10990)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6610)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6554)()
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /home/k/anaconda3/lib/python3.5/site-packages/pandas/tseries/index.py in insert(self, loc, item)
#    1735         try:
# -> 1736             new_dates = np.concatenate((self[:loc].asi8, [item.view(np.int64)],
#    1737                                         self[loc:].asi8))
#
# AttributeError: 'int' object has no attribute 'view'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5602449e35a8> in <module>()
# ----> 1 df.set_value(5,'year', '2016-2017')
#
# /home/k/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in set_value(self, index, col, value, takeable)
#    1867
#    1868             # set using a non-recursive method & reset the cache
# -> 1869             self.loc[index, col] = value
#    1870             self._item_cache.pop(col, None)
#    1871
#
# /home/k/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     130             key = com._apply_if_callable(key, self.obj)
#     131         indexer = self._get_setitem_indexer(key)
# --> 132         self._setitem_with_indexer(indexer, value)
#     133
#     134     def _has_valid_type(self, k, axis):
#
# /home/k/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     299                     # so the object is the same
#     300                     index = self.obj._get_axis(i)
# --> 301                     labels = index.insert(len(index), key)
#     302                     self.obj._data = self.obj.reindex_axis(labels, i)._data
#     303                     self.obj._maybe_update_cacher(clear=True)
#
# /home/k/anaconda3/lib/python3.5/site-packages/pandas/tseries/index.py in insert(self, loc, item)
#    1747                 return self.asobject.insert(loc, item)
#    1748             raise TypeError(
# -> 1749                 "cannot insert DatetimeIndex with incompatible label")
#    1750
#    1751     def delete(self, loc):
#
# TypeError: cannot insert DatetimeIndex with incompatible label

# %%
df
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_values('year')
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_values('year', ascending=False)
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012

# %%
df.sort_values('PTS')
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_values('PTS', na_position='first')
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016

# %%
df['GP'] = [25, 80, 78,78, 26, None]

# %%
df
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN

# %%
df.sort_values(['GP', 'PTS'])
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN

# %%
df.sort_values(['GP', 'PTS'], ascending=[False, False])
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN

# %%
df.sort_values(['GP', 'PTS'], ascending=[False, True])
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN

# %% [markdown]
# ##  Sort Index

# %%
df.sort_index()
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN

# %%
df.sort_index(ascending=False)
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25

# %%
df.sort_index(axis=0)
# Out:
#      %3 PTS   3PA  3PM League   PTS          Team       per3       year  GP
# 0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016  25
# 1  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015  80
# 2  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014  78
# 3  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013  78
# 4  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012  26
# 5       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017 NaN

# %%
df.sort_index(axis=1)
# Out:
#      %3 PTS   3PA  3PM  GP League   PTS          Team       per3       year
# 0  0.478125  11.1  5.1  25    NBA  32.0  Golden State  47.812500  2015-2016
# 1  0.453782   8.1  3.6  80    NBA  23.8  Golden State  45.378151  2014-2015
# 2  0.412500   7.9  3.3  78    NBA  24.0  Golden State  41.250000  2013-2014
# 3  0.458515   7.7  3.5  78    NBA  22.9  Golden State  45.851528  2012-2013
# 4  0.428571   4.7  2.1  26    NBA  14.7  Golden State  42.857143  2011-2012
# 5       NaN   NaN  NaN NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#         year       per3          Team   PTS League  GP  3PM   3PA    %3 PTS
# 0  2015-2016  47.812500  Golden State  32.0    NBA  25  5.1  11.1  0.478125
# 1  2014-2015  45.378151  Golden State  23.8    NBA  80  3.6   8.1  0.453782
# 2  2013-2014  41.250000  Golden State  24.0    NBA  78  3.3   7.9  0.412500
# 3  2012-2013  45.851528  Golden State  22.9    NBA  78  3.5   7.7  0.458515
# 4  2011-2012  42.857143  Golden State  14.7    NBA  26  2.1   4.7  0.428571
# 5  2016-2017        NaN           NaN   NaN    NaN NaN  NaN   NaN       NaN
